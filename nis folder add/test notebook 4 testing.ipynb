# %% [markdown]
# this is a notebook
#
# and this is some markdown
#
# awesome

# %%
# %python
# this is acutalloyt arzoa
print(2 + 2 + 2 + 2)

# %%
# %sql

select 1;

# %%
# %sql

select 2;

# %%
dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

# %% [markdown]
# this was added on databricks. THIS SENTENCE WAS ADDED VIA GITHUB UI AND SHOULD BE PULLED
